# %%
import os

for root, dirs, files in os.walk("."): 
    for f in files: 
        fullpath = os.path.join(root,f) 
        if fullpath.endswith(".md"): 
            print(fullpath)
# Out:
#   File "<ipython-input-2-68a52b03c7e1>", line 4
#     fullpath = os.path.join(root,f)
#            ^
# IndentationError: expected an indented block
