# %%
import os
import re

# This script is designed to fix the problem with pandoc and github 
# incompatability. 

'''
Incompatablity. Github needs relative image addressing for each README.md page

Pandoc needs relative addressing from where pandoc is run.

Clone repository
Find all *.md file and paths
for file in files:
    Read each *.md file in
    prepend the relative path change to each of the images
    write file out with new filename XXXX.pandoc.md

run pandoc 

remove all *.pandoc.md files

'''

# %%
def findAllmarkdown():
    '''
    Call from the current directory
    TODO: make it so it takes a path to start with. 
    '''
    mdlist = []

    for root, dirs, files in os.walk("."): 
        for f in files: 
            fullpath = os.path.join(root,f) 
            if fullpath.endswith(".md"):
                mdlist.append((fullpath, root, f))

    return mdlist


def findImageMarkdown(file, path):
    '''
    Input: a file
    Output: prints a list of Image links
    '''
    f = open(file)
    pattern = "!\[(.*?)\]\((.*?)\)"
    for line in f.readlines():
        test= re.match(pattern, line)
        if test != None:
            #print(line)
            derp = prependPath(line,path)
            #print(derp)
    return

def prependPath(line, path):
    relpath = line.split('(')
    dirstruct = path.split('/')
    relpathstruct = relpath[1].split('/')
    print(dirstruct)
    print(relpathstruct)
    print('.....')
  
    if len(relpathstruct)>1:
        print(dirstruct[0],relpathstruct[1])
        if dirstruct[0] == relpathstruct[1]:
            print('orig: '+ relpath)
    else:
        print('new:  '+path+'/'+ ' ' +relpath[1])
        #print(path+'/'+derp[1])
    print('==========')

# %%
filelist = []
filelist = findAllmarkdown()

FULLPATH = 0
ROOTPATH = 1
FILENAME = 2

for file in filelist:
    #print(file[0])
    findImageMarkdown(file[FULLPATH],file[ROOTPATH])
# Out:
# ['.']
# ['CurrentBlockDiagram2.png){ width=250px}\n']
# .....
# new:  ./ CurrentBlockDiagram2.png){ width=250px}
#
# ==========
# ['.']
# ['Progress.jpg)\n']
# .....
# new:  ./ Progress.jpg)
#
# ==========
# ['.', 'System']
# ['CurrentBlockDiagram2.png)\n']
# .....
# new:  ./System/ CurrentBlockDiagram2.png)
#
# ==========
# ['.', 'System', 'PressureRelief']
# ['System', 'RawDesigns', 'PRV_sketch.jpg)\n']
# .....
# . RawDesigns
# ==========
# ['.', 'System', 'PressureRelief']
# ['System', 'Images', 'PRV_built.jpg)\n']
# .....
# . Images
# ==========
# ['.', 'System', 'Diagrams']
# ['PipeView.jpg)\n']
# .....
# new:  ./System/Diagrams/ PipeView.jpg)
#
# ==========
# ['.', 'System', 'Diagrams']
# ['BlockDiagramv1.1.png)\n']
# .....
# new:  ./System/Diagrams/ BlockDiagramv1.1.png)
#
# ==========
# ['.', 'System', 'Diagrams']
# ['EEequivalent.jpg)\n']
# .....
# new:  ./System/Diagrams/ EEequivalent.jpg)
#
# ==========
# ['.', 'System', 'AirPressureDelivery']
# ['pvc_shop_vac_coupler.JPG)\n']
# .....
# new:  ./System/AirPressureDelivery/ pvc_shop_vac_coupler.JPG)
#
# ==========
# ['.', 'System', 'AirSource']
# ['ShopVac.jpg)\n']
# .....
# new:  ./System/AirSource/ ShopVac.jpg)
#
# ==========
# ['.', 'System', 'AirDistrubution']
# ['AirDistribution.jpg)\n']
# .....
# new:  ./System/AirDistrubution/ AirDistribution.jpg)
#
# ==========
# ['.', 'System', 'LowPressureManometer']
# ['manometerDrawing3.jpg)\n']
# .....
# new:  ./System/LowPressureManometer/ manometerDrawing3.jpg)
#
# ==========
# ['.', 'System', 'LowPressureManometer']
# ['ManometerSide.jpg)\n']
# .....
# new:  ./System/LowPressureManometer/ ManometerSide.jpg)
#
# ==========
# ['.', 'System', 'LowPressureManometer']
# ['ManometerConnect.jpg)\n']
# .....
# new:  ./System/LowPressureManometer/ ManometerConnect.jpg)
#
# ==========
# ['.', 'System', 'LowPressureManometer']
# ['manometer_success.jpg)\n']
# .....
# new:  ./System/LowPressureManometer/ manometer_success.jpg)
#
# ==========
# ['.', 'System', 'ElectoMechanicalControlSystem']
# ['AsBuilt.jpg)\n']
# .....
# new:  ./System/ElectoMechanicalControlSystem/ AsBuilt.jpg)
#
# ==========
# ['.', 'System', 'ElectoMechanicalControlSystem']
# ['StateDiagram.jpg)\n']
# .....
# new:  ./System/ElectoMechanicalControlSystem/ StateDiagram.jpg)
#
# ==========
# ['.', 'System', 'ElectoMechanicalControlSystem']
# ['Refined_page2.jpg)\n']
# .....
# new:  ./System/ElectoMechanicalControlSystem/ Refined_page2.jpg)
#
# ==========
# ['.', 'System', 'ElectoMechanicalControlSystem']
# ['TimingChart.jpg)\n']
# .....
# new:  ./System/ElectoMechanicalControlSystem/ TimingChart.jpg)
#
# ==========
# ['.', 'System', 'PressureControlValve']
# ['PCVv3.png)\n']
# .....
# new:  ./System/PressureControlValve/ PCVv3.png)
#
# ==========
# ['.', 'System', 'PressureControlValve']
# ['PCVv2_sketch.jpg)\n']
# .....
# new:  ./System/PressureControlValve/ PCVv2_sketch.jpg)
#
# ==========
# ['.', 'System', 'Ventilator']
# ['Ambu_schematic.jpg)\n']
# .....
# new:  ./System/Ventilator/ Ambu_schematic.jpg)
#
# ==========
# ['.', 'System', 'Ventilator']
# ['flow_diagram.jpg)\n']
# .....
# new:  ./System/Ventilator/ flow_diagram.jpg)
#
# ==========
# ['.', 'System', 'Ventilator', 'ValveControl']
# ['', 'System', 'SystemBlockDiagram4.png)\n']
# .....
# . System
# ==========
# ['.', 'System', 'AmbuBag']
# ['ambubagdrawing.jpg)\n']
# .....
# new:  ./System/AmbuBag/ ambubagdrawing.jpg)
#
# ==========
# ['.', 'System', 'AirFilter']
# ['Drawing1.jpg)\n']
# .....
# new:  ./System/AirFilter/ Drawing1.jpg)
#
# ==========
# ['.', 'System', 'AirFilter']
# ['Drawing2.jpg)\n']
# .....
# new:  ./System/AirFilter/ Drawing2.jpg)
#
# ==========
# ['.', 'System', 'AirFilter']
# ['Drawing3.jpg)\n']
# .....
# new:  ./System/AirFilter/ Drawing3.jpg)
#
# ==========
# ['.', 'System', 'AirFilter', 'v1']
# ['AirflowBox.jpg)\n']
# .....
# new:  ./System/AirFilter/v1/ AirflowBox.jpg)
#
# ==========
# ['.', 'Documents']
# ['Documents', 'prd1small_1_1.jpg)\n']
# .....
# . prd1small_1_1.jpg)
#
# ==========

# %%
pwd
# Out:
# '/Users/Brian/Documents/GitHub/OpenVert'
